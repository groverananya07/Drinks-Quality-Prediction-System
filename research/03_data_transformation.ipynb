# %%
import os

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# '/Users/ananyagrover/Drinks-Quality-Prediction-System'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataTransformationConfig:
    root_dir:Path
    data_path:Path

# %%
from mlProject.constants import *
from mlProject.utils.common import read_yaml,create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath=CONFIG_FILE_PATH,
        params_filepath=PARAMS_FILE_PATH,
        schema_filepath=SCHEMA_FILE_PATH
    ):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_transformation_config(self) -> DataTransformationConfig:
        config = self.config.data_transformation

        create_directories([config.root_dir])

        data_transformation_config = DataTransformationConfig(
            root_dir=config.root_dir,
            data_path=config.data_path,
        )

        return data_transformation_config

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from mlProject import logger

# %%
class DataTransformation:
    def __init__(self, config: DataTransformationConfig):
        self.config = config

    # You can add scaler, PCA, feature engineering etc. here
    # Right now only train-test split because dataset is already cleaned

    def train_test_spliting(self):
        data = pd.read_csv(self.config.data_path)

        # Split into train and test sets (default 75/25)
        train, test = train_test_split(data)

        train.to_csv(
            os.path.join(self.config.root_dir, "train.csv"),
            index=False
        )

        test.to_csv(
            os.path.join(self.config.root_dir, "test.csv"),
            index=False
        )

        logger.info("Splited data into training and test sets")
        logger.info(train.shape)
        logger.info(test.shape)

        print(train.shape)
        print(test.shape)

# %%
try:
    config = ConfigurationManager()
    data_transformation_config = config.get_data_transformation_config()
    data_transformation = DataTransformation(config=data_transformation_config)
    data_transformation.train_test_spliting()
except Exception as e:
    raise e
# Out:
# [2026-07-05 22:08:45,788: INFO: common: yaml file: config/config.yaml loaded successfully]
# [2026-07-05 22:08:45,793: INFO: common: yaml file: params.yaml loaded successfully]
# [2026-07-05 22:08:45,795: INFO: common: yaml file: schema.yaml loaded successfully]
# [2026-07-05 22:08:45,798: INFO: common: created directory at: artifacts]
# [2026-07-05 22:08:45,802: INFO: common: created directory at: artifacts/data_transformation]
# [2026-07-05 22:08:45,848: INFO: 176054595: Splited data into training and test sets]
# [2026-07-05 22:08:45,849: INFO: 176054595: (1199, 12)]
# [2026-07-05 22:08:45,849: INFO: 176054595: (400, 12)]
# (1199, 12)
# (400, 12)
